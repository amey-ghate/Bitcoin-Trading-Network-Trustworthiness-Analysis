# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import datetime
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# **ALL**

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Datasets/Social Media/All.csv')

# %%
G = nx.from_pandas_edgelist(df, 'Source', 'Target', create_using=nx.DiGraph)

# %%
plt.title('Network for ratings = -10 ALL')
nx.draw(G, with_labels=True, node_color='lightblue', node_size=500, edge_color='gray', font_size=10)

# %%
G = nx.from_pandas_edgelist(df, 'Source', 'Target')
core_numbers = nx.core_number(G)
all_cliques = list(nx.find_cliques(G))

# Find the maximum clique size
max_clique_size = max(len(clique) for clique in all_cliques)
print("\nMaximum Clique Size:", max_clique_size)

# Find the maximum core number
max_core_number = max(core_numbers.values())
print("\nMaximum Core Size:",max_core_number)
# Out:
# Maximum Clique Size: 8
#
# Maximum Core Size: 11

# %%
G = nx.from_pandas_edgelist(df, 'Source', 'Target','Rating',create_using=nx.DiGraph)

# %%
for node in G.nodes():
    # Calculate the average rating received by the node based on its incoming edges
    # If the node has no incoming edges, set the rating to None
    ratings = [G.edges[edge]['Rating'] for edge in G.in_edges(node)]
    if ratings:
        average_rating = sum(ratings) / len(ratings)
    else:
        average_rating = None
    G.nodes[node]['Ratings'] = average_rating

# %%
 assortativity = nx.attribute_assortativity_coefficient(G, 'Ratings')
 print(assortativity)
# Out:
# 0.0776470588235294

# %% [markdown]
# Only Target

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Datasets/Social Media/only_target.csv')
G = nx.from_pandas_edgelist(df, 'Source', 'Target', create_using=nx.DiGraph)
plt.title('Network for ratings = -10 ALL')
nx.draw(G, with_labels=True, node_color='lightblue', node_size=500, edge_color='gray', font_size=10)

# %%
G = nx.from_pandas_edgelist(df, 'Source', 'Target','Rating')
core_numbers = nx.core_number(G)
all_cliques = list(nx.find_cliques(G))

# Find the maximum clique size
max_clique_size = max(len(clique) for clique in all_cliques)
print("\nMaximum Clique Size:", max_clique_size)

# Find the maximum core number
max_core_number = max(core_numbers.values())
print("\nMaximum Core Size:",max_core_number)
# Out:
# Maximum Clique Size: 7
#
# Maximum Core Size: 6

# %%
all_cliques
# Out:
# [[3744, 2017, 3760, 3756, 3757, 3759],
#  [4701, 4676, 4668],
#  [4677, 4667, 4668],
#  [4743, 4688, 4686],
#  [4744, 4676],
#  [4683, 4678, 4531],
#  [4683, 4678, 4679, 4680, 4681, 4682, 4684],
#  [4683, 4678, 4679, 4680, 4681, 4682, 4686],
#  [4683, 4679, 4688, 4680, 4681, 4682, 4686],
#  [4683, 4686, 4676],
#  [4683, 4667, 4672, 4673],
#  [4683, 4667, 4654, 4673, 4666, 4531, 4661],
#  [4683, 4667, 4654, 4673, 4668],
#  [4683, 4667, 4654, 4675, 4666, 4531, 4661],
#  [4683, 4667, 4654, 4675, 4668],
#  [4683, 4667, 4654, 4676, 4668],
#  [4669, 4667, 4668]]

# %%
G = nx.from_pandas_edgelist(df, 'Source', 'Target','Rating',create_using=nx.DiGraph)

# %%
for node in G.nodes():
    # Calculate the average rating received by the node based on its incoming edges
    # If the node has no incoming edges, set the rating to None
    ratings = [G.edges[edge]['Rating'] for edge in G.in_edges(node)]
    if ratings:
        average_rating = sum(ratings) / len(ratings)
    else:
        average_rating = None
    G.nodes[node]['Ratings'] = average_rating

# %%
 assortativity = nx.attribute_assortativity_coefficient(G, 'Ratings')
 print(assortativity)
# Out:
# 0.24507635597682997

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Datasets/Social Media/test.csv')
G = nx.from_pandas_edgelist(df, 'Source', 'Target', create_using=nx.DiGraph)
plt.title('Network for ratings = -10 ALL')
nx.draw(G, with_labels=True, node_color='lightblue', node_size=500, edge_color='gray', font_size=10)

# %%
G = nx.from_pandas_edgelist(df, 'Source', 'Target','Ratings',create_using=nx.DiGraph)

# %%
for node in G.nodes():
    # Calculate the average rating received by the node based on its incoming edges
    # If the node has no incoming edges, set the rating to None
    ratings = [G.edges[edge]['Ratings'] for edge in G.in_edges(node)]
    if ratings:
        average_rating = sum(ratings) / len(ratings)
    else:
        average_rating = None
    G.nodes[node]['Ratings'] = average_rating

# %%
 assortativity = nx.attribute_assortativity_coefficient(G, 'Ratings')
 print(assortativity)
# Out:
# 0.11751825228399819

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Datasets/Social Media/non_target.csv')
G = nx.from_pandas_edgelist(df, 'Source', 'Target', create_using=nx.DiGraph)
plt.title('Network for ratings = -10 ALL')
nx.draw(G, with_labels=True, node_color='lightblue', node_size=500, edge_color='gray', font_size=10)

# %%
G = nx.from_pandas_edgelist(df, 'Source', 'Target')
core_numbers = nx.core_number(G)
all_cliques = list(nx.find_cliques(G))

# Find the maximum clique size
max_clique_size = max(len(clique) for clique in all_cliques)
print("\nMaximum Clique Size:", max_clique_size)

# Find the maximum core number
max_core_number = max(core_numbers.values())
print("\nMaximum Core Size:",max_core_number)
# Out:
# Maximum Clique Size: 2
#
# Maximum Core Size: 6

# %%
G = nx.from_pandas_edgelist(df, 'Source', 'Target','Ratings',create_using=nx.DiGraph)

# %%
for node in G.nodes():
    # Calculate the average rating received by the node based on its incoming edges
    # If the node has no incoming edges, set the rating to None
    ratings = [G.edges[edge]['Ratings'] for edge in G.in_edges(node)]
    if ratings:
        average_rating = sum(ratings) / len(ratings)
    else:
        average_rating = None
    G.nodes[node]['Ratings'] = average_rating

# %%
 assortativity = nx.attribute_assortativity_coefficient(G, 'Ratings')
 print(assortativity)
# Out:
# 0.0

# %%
G = nx.from_pandas_edgelist(df, 'Source', 'Target','Ratings',create_using=nx.DiGraph)

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Datasets/Social Media/soc-sign-bitcoinotc.csv',header=None, names=['Source', 'Target', 'Rating', 'Time'])

# %%
G = nx.DiGraph()

# Add nodes and edges from the DataFrame
for index, row in df.iterrows():
    G.add_edge(row['Source'], row['Target'], weight=row['Rating'])

# %%
for node in G.nodes():
    # Calculate the average rating received by the node based on its incoming edges
    # If the node has no incoming edges, set the rating to None
    ratings = [G.edges[edge]['weight'] for edge in G.in_edges(node)]
    if ratings:
        average_rating = sum(ratings) / len(ratings)
    else:
        average_rating = None
    G.nodes[node]['Ratings'] = average_rating

# Define the list of nodes
nodes_to_analyze = [2498	,2574	,2017	,2657	,3744	,3756	,3757	,3759	,3760	,4350	,4531	,4654	,4661	,4666	,4673	,4672	,4675	,4677	,4681	,4679	,4668	,4667	,4669	,4676	,4678	,4680	,4682	,4683	,4686	,4688	,4684	,4701	,4645	,4743	,4744	,4747]

# %%
for node in nodes_to_analyze:
    print(f"Metrics for network containing node {node}:")

    # Extract subgraph for the current node
    subgraph = nx.subgraph(G, [node] + list(G.neighbors(node)))

    # Calculate number of nodes in the subgraph
    num_nodes = subgraph.number_of_nodes()
    print("Number of nodes in the subgraph:", num_nodes)

    # Plot the network
    plot_network(subgraph)

    # Calculate network metrics
    degree_centrality = nx.degree_centrality(subgraph)
    closeness_centrality = nx.closeness_centrality(subgraph)
    betweenness_centrality = nx.betweenness_centrality(subgraph)
    eigenvector_centrality = nx.eigenvector_centrality(subgraph)
    clustering_coefficient = nx.average_clustering(subgraph)
    assortativity = nx.attribute_assortativity_coefficient(subgraph, 'Ratings')

    # Print network metrics
    print("Degree Centrality:", degree_centrality)
    print("Closeness Centrality:", closeness_centrality)
    print("Betweenness Centrality:", betweenness_centrality)
    print("Eigenvector Centrality:", eigenvector_centrality)
    print("Clustering Coefficient:", clustering_coefficient)
    print("Assortativity:", assortativity)
    print()
# Out:
# This cell output is too large and can only be displayed while logged in.

# %%
def plot_network(subgraph):
    plt.figure(figsize=(8, 6))
    pos = nx.spring_layout(subgraph)  # Layout for the nodes
    nx.draw(subgraph, pos, with_labels=True, node_color='lightblue', node_size=800, font_size=10, arrows=False)
    plt.title('Network Visualization')
    plt.show()

# %%
df_filt=df['Source'] in

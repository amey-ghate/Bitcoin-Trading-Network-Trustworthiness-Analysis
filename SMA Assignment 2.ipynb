# %%
import networkx as nx
import math
import pandas as pd
import sys

# %%
df = pd.read_csv('soc-sign-bitcoinotc-labeled.csv')
df
# Out:
#        Source  Target  Rating        Time
# 0           6       2       4  1289241912
# 1           6       5       2  1289241942
# 2           1      15       1  1289243140
# 3           4       3       7  1289245277
# 4          13      16       8  1289254254
# ...       ...     ...     ...         ...
# 35587    4499    1810       1  1453612482
# 35588    2731    3901       5  1453679428
# 35589    2731    4897       5  1453679434
# 35590      13    1128       1  1453679633
# 35591    1128      13       2  1453684324
#
# [35592 rows x 4 columns]

# %%
rated_10_nodes = df[df['Rating'] == 10]['Target'].unique()
most_common_ratings_given_10 = {node: df[df['Source'] == node]['Rating'].mode().tolist() for node in rated_10_nodes}

# Nodes most commonly rated -10
rated_minus_10_nodes = df[df['Rating'] == -10]['Target'].unique()
most_common_ratings_given_minus_10 = {node: df[df['Source'] == node]['Rating'].mode().tolist() for node in rated_minus_10_nodes}

print("Nodes most commonly rated 10 and their most common ratings given out:")
for node, ratings in most_common_ratings_given_10.items():
    print(f"Node {node} gives out ratings {ratings}")

print("\nNodes most commonly rated -10 and their most common ratings given out:")
for node, ratings in most_common_ratings_given_minus_10.items():
    print(f"Node {node} gives out ratings {ratings}")
# Out:
# Nodes most commonly rated 10 and their most common ratings given out:
# Node 25 gives out ratings []
# Node 1 gives out ratings [1]
# Node 127 gives out ratings [1, 10]
# Node 119 gives out ratings [10]
# Node 202 gives out ratings [1]
# Node 257 gives out ratings [5]
# Node 284 gives out ratings [1]
# Node 283 gives out ratings [1, 2]
# Node 45 gives out ratings [1, 2]
# Node 7 gives out ratings [1]
# Node 395 gives out ratings [-10]
# Node 201 gives out ratings [1]
# Node 451 gives out ratings [1, 10]
# Node 51 gives out ratings [1]
# Node 104 gives out ratings [1]
# Node 499 gives out ratings [1]
# Node 111 gives out ratings [1]
# Node 484 gives out ratings [1]
# Node 529 gives out ratings [10]
# Node 300 gives out ratings [1, 3, 10]
# Node 570 gives out ratings [1]
# Node 571 gives out ratings [1]
# Node 159 gives out ratings [1]
# Node 587 gives out ratings [1]
# Node 623 gives out ratings [-10, 1, 10]
# Node 304 gives out ratings [1]
# Node 200 gives out ratings [1]
# Node 342 gives out ratings [2, 4]
# Node 635 gives out ratings [1]
# Node 651 gives out ratings [1, 2]
# Node 650 gives out ratings [1]
# Node 523 gives out ratings [1]
# Node 720 gives out ratings [1, 10]
# Node 64 gives out ratings [1]
# Node 184 gives out ratings [1]
# Node 732 gives out ratings [2]
# Node 770 gives out ratings [2]
# Node 814 gives out ratings [10]
# Node 780 gives out ratings [1]
# Node 109 gives out ratings [1]
# Node 847 gives out ratings [1]
# Node 908 gives out ratings [1]
# Node 548 gives out ratings [1]
# Node 832 gives out ratings [3]
# Node 920 gives out ratings [1]
# Node 894 gives out ratings [1]
# Node 534 gives out ratings [1]
# Node 610 gives out ratings [1]
# Node 923 gives out ratings [1]
# Node 554 gives out ratings [2]
# Node 1013 gives out ratings [1, 3]
# Node 241 gives out ratings [-4, 1, 2, 3, 6, 8, 10]
# Node 475 gives out ratings [2]
# Node 606 gives out ratings [1]
# Node 777 gives out ratings [1]
# Node 1068 gives out ratings [1]
# Node 530 gives out ratings [1]
# Node 1076 gives out ratings []
# Node 1014 gives out ratings [1]
# Node 1094 gives out ratings [1]
# Node 492 gives out ratings [1]
# Node 1119 gives out ratings [1]
# Node 953 gives out ratings [1]
# Node 1122 gives out ratings [10]
# Node 922 gives out ratings [10]
# Node 882 gives out ratings [1]
# Node 710 gives out ratings [1]
# Node 1133 gives out ratings [-5, 1, 3, 10]
# Node 1092 gives out ratings [1]
# Node 1140 gives out ratings []
# Node 134 gives out ratings [1]
# Node 593 gives out ratings [2]
# Node 1174 gives out ratings [1]
# Node 959 gives out ratings [3, 10]
# Node 198 gives out ratings [1]
# Node 1191 gives out ratings [1]
# Node 500 gives out ratings [10]
# Node 1100 gives out ratings [1]
# Node 1084 gives out ratings [5]
# Node 1257 gives out ratings [1, 2, 3]
# Node 1037 gives out ratings [2]
# Node 1261 gives out ratings [10]
# Node 1166 gives out ratings [1, 2]
# Node 270 gives out ratings [1]
# Node 1277 gives out ratings [1]
# Node 1291 gives out ratings [1, 10]
# Node 626 gives out ratings [1]
# Node 540 gives out ratings [1]
# Node 1260 gives out ratings [10]
# Node 566 gives out ratings [1]
# Node 1065 gives out ratings [1]
# Node 1326 gives out ratings [10]
# Node 911 gives out ratings [10]
# Node 1340 gives out ratings [-10]
# Node 518 gives out ratings [1]
# Node 1358 gives out ratings [1, 2, 10]
# Node 1328 gives out ratings [1]
# Node 1267 gives out ratings [1]
# Node 1368 gives out ratings [3]
# Node 921 gives out ratings [3]
# Node 1201 gives out ratings [2, 3]
# Node 546 gives out ratings [1]
# Node 1207 gives out ratings [1]
# Node 801 gives out ratings [1, 2]
# Node 1437 gives out ratings [1]
# Node 1501 gives out ratings []
# Node 1545 gives out ratings []
# Node 1600 gives out ratings []
# Node 1290 gives out ratings [1]
# Node 1566 gives out ratings [1]
# Node 1663 gives out ratings []
# Node 545 gives out ratings [1]
# Node 1669 gives out ratings [1]
# Node 1701 gives out ratings [1]
# Node 1386 gives out ratings [1]
# Node 1591 gives out ratings [1]
# Node 1744 gives out ratings [1]
# Node 1779 gives out ratings [1]
# Node 23 gives out ratings [1]
# Node 1877 gives out ratings []
# Node 178 gives out ratings [1]
# Node 1840 gives out ratings [1]
# Node 1839 gives out ratings [2, 5, 8]
# Node 1771 gives out ratings [1]
# Node 1896 gives out ratings [1]
# Node 1957 gives out ratings [1]
# Node 1855 gives out ratings []
# Node 2078 gives out ratings []
# Node 2080 gives out ratings [1]
# Node 1615 gives out ratings [1]
# Node 2082 gives out ratings [10]
# Node 309 gives out ratings [-10, 1]
# Node 35 gives out ratings [1]
# Node 2028 gives out ratings [1]
# Node 2214 gives out ratings [1]
# Node 2125 gives out ratings [1]
# Node 722 gives out ratings [1]
# Node 1620 gives out ratings [1]
# Node 2200 gives out ratings [1, 10]
# Node 2305 gives out ratings [10]
# Node 988 gives out ratings [1]
# Node 2076 gives out ratings [-10, 1, 10]
# Node 1121 gives out ratings [1, 10]
# Node 2241 gives out ratings [1, 10]
# Node 1899 gives out ratings [1]
# Node 4 gives out ratings [1]
# Node 1731 gives out ratings [1]
# Node 2067 gives out ratings [1]
# Node 2377 gives out ratings [10]
# Node 2313 gives out ratings [1]
# Node 2167 gives out ratings [1]
# Node 1396 gives out ratings [1]
# Node 1185 gives out ratings [1]
# Node 905 gives out ratings [1]
# Node 249 gives out ratings [1]
# Node 2370 gives out ratings [2, 5]
# Node 2342 gives out ratings [1, 10]
# Node 2567 gives out ratings [8, 9]
# Node 2198 gives out ratings []
# Node 2574 gives out ratings [2]
# Node 2601 gives out ratings [3, 5, 7]
# Node 2658 gives out ratings [1]
# Node 2669 gives out ratings [2, 6]
# Node 2671 gives out ratings [5]
# Node 2631 gives out ratings [10]
# Node 2629 gives out ratings []
# Node 2632 gives out ratings [10]
# Node 2628 gives out ratings [10]
# Node 1543 gives out ratings [2]
# Node 2634 gives out ratings []
# Node 2666 gives out ratings [2]
# Node 2570 gives out ratings [2, 5]
# Node 2571 gives out ratings [1]
# Node 1810 gives out ratings [1]
# Node 2548 gives out ratings []
# Node 2682 gives out ratings [10]
# Node 2176 gives out ratings [1]
# Node 2680 gives out ratings [10]
# Node 2683 gives out ratings [-10]
# Node 2684 gives out ratings [-10]
# Node 2685 gives out ratings [10]
# Node 2118 gives out ratings [1]
# Node 57 gives out ratings [1]
# Node 2672 gives out ratings [10]
# Node 2674 gives out ratings [3]
# Node 2700 gives out ratings [1, 5]
# Node 2721 gives out ratings []
# Node 2676 gives out ratings [1]
# Node 242 gives out ratings [1, 2]
# Node 2647 gives out ratings [1]
# Node 2782 gives out ratings [1]
# Node 2427 gives out ratings [1]
# Node 1675 gives out ratings [1]
# Node 2688 gives out ratings [1]
# Node 1953 gives out ratings [1]
# Node 1383 gives out ratings [1]
# Node 2953 gives out ratings []
# Node 2733 gives out ratings [1]
# Node 2485 gives out ratings [1]
# Node 2642 gives out ratings [1]
# Node 2246 gives out ratings [1]
# Node 2635 gives out ratings [1]
# Node 2896 gives out ratings [1]
# Node 3125 gives out ratings [10]
# Node 3129 gives out ratings [1]
# Node 448 gives out ratings [1, 6, 10]
# Node 1743 gives out ratings [8]
# Node 3018 gives out ratings [1]
# Node 3198 gives out ratings [10]
# Node 1271 gives out ratings [1]
# Node 3246 gives out ratings [1]
# Node 2763 gives out ratings [1]
# Node 3260 gives out ratings [4]
# Node 3223 gives out ratings [1]
# Node 3239 gives out ratings [1]
# Node 3119 gives out ratings [1]
# Node 1403 gives out ratings [1]
# Node 2388 gives out ratings [1]
# Node 1363 gives out ratings [-10]
# Node 3293 gives out ratings []
# Node 1366 gives out ratings [1]
# Node 3333 gives out ratings [1]
# Node 1656 gives out ratings [2]
# Node 3377 gives out ratings [3]
# Node 3367 gives out ratings [-10, -2, 3]
# Node 1217 gives out ratings [1]
# Node 1018 gives out ratings [1]
# Node 2437 gives out ratings [1]
# Node 1352 gives out ratings [1]
# Node 3484 gives out ratings [10]
# Node 3483 gives out ratings [10]
# Node 2838 gives out ratings [1]
# Node 3208 gives out ratings [1, 3]
# Node 230 gives out ratings [2]
# Node 135 gives out ratings [1]
# Node 3552 gives out ratings []
# Node 3555 gives out ratings []
# Node 3562 gives out ratings [8]
# Node 3563 gives out ratings [10]
# Node 3564 gives out ratings [8]
# Node 3565 gives out ratings [8]
# Node 2897 gives out ratings [1]
# Node 160 gives out ratings [1]
# Node 896 gives out ratings []
# Node 3451 gives out ratings [1]
# Node 1318 gives out ratings [-10]
# Node 3689 gives out ratings [1]
# Node 3731 gives out ratings [1]
# Node 3744 gives out ratings [10]
# Node 1764 gives out ratings [1]
# Node 2962 gives out ratings [1]
# Node 1948 gives out ratings [1]
# Node 1670 gives out ratings [2]
# Node 29 gives out ratings [1]
# Node 1967 gives out ratings [1]
# Node 535 gives out ratings [1, 2]
# Node 2173 gives out ratings [1]
# Node 493 gives out ratings [1]
# Node 2438 gives out ratings [1]
# Node 3736 gives out ratings [1]
# Node 3394 gives out ratings [1]
# Node 2017 gives out ratings [1]
# Node 3756 gives out ratings [-10]
# Node 3757 gives out ratings [-10]
# Node 3759 gives out ratings [-10]
# Node 3760 gives out ratings [-10]
# Node 2296 gives out ratings [1]
# Node 2934 gives out ratings [-10]
# Node 1802 gives out ratings [1]
# Node 2625 gives out ratings [1]
# Node 3699 gives out ratings [1]
# Node 2484 gives out ratings [1]
# Node 2903 gives out ratings [1]
# Node 1933 gives out ratings [1]
# Node 3861 gives out ratings [10]
# Node 3820 gives out ratings [1]
# Node 3878 gives out ratings [1]
# Node 3888 gives out ratings [1, 10]
# Node 3500 gives out ratings [10]
# Node 3735 gives out ratings [1]
# Node 3669 gives out ratings [1]
# Node 3974 gives out ratings [5, 10]
# Node 2495 gives out ratings [5]
# Node 3975 gives out ratings []
# Node 3598 gives out ratings [1]
# Node 3996 gives out ratings [10]
# Node 361 gives out ratings [1]
# Node 4007 gives out ratings [2]
# Node 2079 gives out ratings [1]
# Node 3781 gives out ratings [1]
# Node 3168 gives out ratings [1]
# Node 4035 gives out ratings [1]
# Node 3655 gives out ratings [1]
# Node 3990 gives out ratings [1]
# Node 3738 gives out ratings [2]
# Node 3445 gives out ratings [1, 2]
# Node 3488 gives out ratings [1]
# Node 3724 gives out ratings [1]
# Node 4036 gives out ratings [2]
# Node 2188 gives out ratings [3]
# Node 1316 gives out ratings [1]
# Node 3219 gives out ratings [1]
# Node 2127 gives out ratings [1, 2]
# Node 2110 gives out ratings [1]
# Node 4075 gives out ratings [1]
# Node 1689 gives out ratings [1]
# Node 2266 gives out ratings [-10]
# Node 3982 gives out ratings [1]
# Node 4198 gives out ratings [1]
# Node 4181 gives out ratings [1]
# Node 13 gives out ratings [1]
# Node 3642 gives out ratings [1]
# Node 4217 gives out ratings [1]
# Node 3898 gives out ratings [1, 6]
# Node 4257 gives out ratings [10]
# Node 4261 gives out ratings [10]
# Node 3527 gives out ratings [1]
# Node 4205 gives out ratings [1]
# Node 3723 gives out ratings [3, 10]
# Node 4098 gives out ratings [1]
# Node 2165 gives out ratings [1]
# Node 2142 gives out ratings [1]
# Node 1098 gives out ratings [3, 5]
# Node 4354 gives out ratings [1, 10]
# Node 3490 gives out ratings [1]
# Node 2777 gives out ratings [1]
# Node 1529 gives out ratings [1]
# Node 4393 gives out ratings [1]
# Node 4395 gives out ratings [8]
# Node 280 gives out ratings [1]
# Node 4172 gives out ratings [1]
# Node 2942 gives out ratings [1]
# Node 4400 gives out ratings [1]
# Node 3025 gives out ratings []
# Node 4515 gives out ratings [1]
# Node 3408 gives out ratings [1]
# Node 4522 gives out ratings [1]
# Node 4197 gives out ratings [1]
# Node 3837 gives out ratings [1]
# Node 2661 gives out ratings [2]
# Node 4546 gives out ratings [1, 2]
# Node 3976 gives out ratings [1]
# Node 2822 gives out ratings [2]
# Node 2498 gives out ratings []
# Node 4639 gives out ratings [10]
# Node 363 gives out ratings [1]
# Node 4654 gives out ratings [-10]
# Node 4646 gives out ratings [2]
# Node 4662 gives out ratings [2]
# Node 4663 gives out ratings [4]
# Node 4661 gives out ratings [-10]
# Node 4666 gives out ratings [-10]
# Node 481 gives out ratings [-10]
# Node 4667 gives out ratings [1]
# Node 4668 gives out ratings [1]
# Node 4669 gives out ratings [-10]
# Node 2045 gives out ratings [1]
# Node 4107 gives out ratings [1]
# Node 4707 gives out ratings [-10]
# Node 2347 gives out ratings [10]
# Node 4733 gives out ratings [-10]
# Node 4569 gives out ratings [1, 3]
# Node 1334 gives out ratings [1]
# Node 4735 gives out ratings [-10]
# Node 4635 gives out ratings [1]
# Node 4482 gives out ratings [1]
# Node 3957 gives out ratings [2]
# Node 4611 gives out ratings [1]
# Node 4659 gives out ratings [-10]
# Node 4823 gives out ratings []
# Node 4824 gives out ratings [10]
# Node 4855 gives out ratings []
# Node 3719 gives out ratings [1]
# Node 4559 gives out ratings [1]
# Node 3897 gives out ratings [1]
# Node 4988 gives out ratings [1, 2, 5]
# Node 4918 gives out ratings [10]
# Node 3725 gives out ratings [1]
# Node 5030 gives out ratings [1]
# Node 547 gives out ratings [2]
# Node 5032 gives out ratings [8]
# Node 5028 gives out ratings [1]
# Node 5029 gives out ratings [1]
# Node 5013 gives out ratings [1]
# Node 5086 gives out ratings [1]
# Node 5132 gives out ratings [2, 10]
# Node 5046 gives out ratings [2]
# Node 5080 gives out ratings [-10, 5]
# Node 3649 gives out ratings [1]
# Node 5162 gives out ratings []
# Node 5163 gives out ratings [10]
# Node 3504 gives out ratings [10]
# Node 5200 gives out ratings [-10]
# Node 5201 gives out ratings [-10]
# Node 5202 gives out ratings [-10]
# Node 5203 gives out ratings [-10]
# Node 5204 gives out ratings []
# Node 3452 gives out ratings [1]
# Node 5237 gives out ratings [10]
# Node 5239 gives out ratings [10]
# Node 5240 gives out ratings []
# Node 5284 gives out ratings [10]
# Node 3714 gives out ratings [1]
# Node 5299 gives out ratings []
# Node 192 gives out ratings [1]
# Node 1690 gives out ratings [1]
# Node 3707 gives out ratings [1]
# Node 5404 gives out ratings [1, 10]
# Node 3630 gives out ratings [2]
# Node 5212 gives out ratings [10]
# Node 5438 gives out ratings [10]
# Node 4753 gives out ratings [1]
# Node 5384 gives out ratings [1]
# Node 5458 gives out ratings [1, 10]
# Node 4291 gives out ratings [1]
# Node 5476 gives out ratings [1]
# Node 5522 gives out ratings [-10, -1, 10]
# Node 2870 gives out ratings [1, 10]
# Node 3828 gives out ratings [1]
# Node 5472 gives out ratings [1]
# Node 4899 gives out ratings [1]
# Node 5521 gives out ratings [-10, 2]
# Node 5473 gives out ratings [-10]
# Node 5551 gives out ratings [1]
# Node 5568 gives out ratings [10]
# Node 5492 gives out ratings [1]
# Node 5618 gives out ratings [10]
# Node 5590 gives out ratings [1, 10]
# Node 5619 gives out ratings [10]
# Node 5622 gives out ratings [1]
# Node 1752 gives out ratings [1]
# Node 5720 gives out ratings []
# Node 5729 gives out ratings [3]
# Node 4649 gives out ratings [1]
# Node 5712 gives out ratings [2]
# Node 5761 gives out ratings [10]
# Node 5759 gives out ratings [1]
# Node 5612 gives out ratings [1]
# Node 5506 gives out ratings [1]
# Node 5824 gives out ratings []
# Node 5826 gives out ratings []
# Node 5859 gives out ratings [1]
# Node 5896 gives out ratings [1]
# Node 5507 gives out ratings [1, 10]
# Node 5439 gives out ratings [1]
# Node 5411 gives out ratings [1]
# Node 5958 gives out ratings [2, 3, 10]
# Node 5955 gives out ratings [1]
# Node 5971 gives out ratings [1]
# Node 5960 gives out ratings []
# Node 5845 gives out ratings []
#
# Nodes most commonly rated -10 and their most common ratings given out:
# Node 315 gives out ratings []
# Node 410 gives out ratings [1, 2, 3, 10]
# Node 467 gives out ratings [1]
# Node 310 gives out ratings [1]
# Node 472 gives out ratings [1]
# Node 463 gives out ratings [1]
# Node 512 gives out ratings [1]
# Node 594 gives out ratings [1]
# Node 672 gives out ratings [5]
# Node 766 gives out ratings [1]
# Node 906 gives out ratings [2]
# Node 984 gives out ratings [2]
# Node 805 gives out ratings [1]
# Node 978 gives out ratings [2]
# Node 832 gives out ratings [3]
# Node 1116 gives out ratings []
# Node 1099 gives out ratings [1, 3]
# Node 710 gives out ratings [1]
# Node 804 gives out ratings [1]
# Node 1145 gives out ratings [-10]
# Node 1143 gives out ratings [4]
# Node 1139 gives out ratings [1, 2, 3, 6, 10]
# Node 957 gives out ratings [-10, 2]
# Node 1140 gives out ratings []
# Node 64 gives out ratings [1]
# Node 787 gives out ratings [1]
# Node 726 gives out ratings [1]
# Node 566 gives out ratings [1]
# Node 1026 gives out ratings [1, 2]
# Node 732 gives out ratings [2]
# Node 492 gives out ratings [1]
# Node 958 gives out ratings [2]
# Node 1211 gives out ratings []
# Node 270 gives out ratings [1]
# Node 1074 gives out ratings [2]
# Node 1277 gives out ratings [1]
# Node 713 gives out ratings []
# Node 135 gives out ratings [1]
# Node 1308 gives out ratings []
# Node 824 gives out ratings [1]
# Node 1329 gives out ratings [1]
# Node 260 gives out ratings []
# Node 1144 gives out ratings []
# Node 1142 gives out ratings []
# Node 1141 gives out ratings []
# Node 1327 gives out ratings []
# Node 1387 gives out ratings []
# Node 1393 gives out ratings []
# Node 1443 gives out ratings [2]
# Node 628 gives out ratings [1]
# Node 44 gives out ratings [1]
# Node 1572 gives out ratings [10]
# Node 1600 gives out ratings []
# Node 309 gives out ratings [-10, 1]
# Node 1609 gives out ratings [1, 3]
# Node 1705 gives out ratings []
# Node 1756 gives out ratings [-1, 1, 2]
# Node 1671 gives out ratings [1]
# Node 25 gives out ratings []
# Node 1853 gives out ratings [1]
# Node 1862 gives out ratings []
# Node 1753 gives out ratings [2]
# Node 1357 gives out ratings [1]
# Node 1363 gives out ratings [-10]
# Node 1956 gives out ratings [1]
# Node 1917 gives out ratings [1]
# Node 1771 gives out ratings [1]
# Node 2096 gives out ratings [2, 3]
# Node 2089 gives out ratings [1]
# Node 61 gives out ratings [2, 3, 4, 8, 10]
# Node 2148 gives out ratings [1, 2]
# Node 1984 gives out ratings [1]
# Node 2209 gives out ratings []
# Node 2225 gives out ratings [1]
# Node 2239 gives out ratings []
# Node 2245 gives out ratings []
# Node 1967 gives out ratings [1]
# Node 1543 gives out ratings [2]
# Node 1719 gives out ratings [8, 10]
# Node 770 gives out ratings [2]
# Node 1955 gives out ratings [-2, 1, 2]
# Node 2251 gives out ratings [1]
# Node 2260 gives out ratings [1]
# Node 2367 gives out ratings [7]
# Node 2265 gives out ratings [1, 2]
# Node 2198 gives out ratings []
# Node 2266 gives out ratings [-10]
# Node 1386 gives out ratings [1]
# Node 2102 gives out ratings [1]
# Node 2370 gives out ratings [2, 5]
# Node 2410 gives out ratings [1]
# Node 2471 gives out ratings [1]
# Node 2498 gives out ratings []
# Node 2434 gives out ratings [1]
# Node 1383 gives out ratings [1]
# Node 1810 gives out ratings [1]
# Node 2516 gives out ratings [4, 5]
# Node 2505 gives out ratings [1]
# Node 2514 gives out ratings [3]
# Node 2539 gives out ratings [1]
# Node 2540 gives out ratings [6, 8]
# Node 2548 gives out ratings []
# Node 2532 gives out ratings []
# Node 2549 gives out ratings [6, 10]
# Node 2208 gives out ratings [1]
# Node 2566 gives out ratings [1]
# Node 2569 gives out ratings [1, 2, 5, 9]
# Node 2571 gives out ratings [1]
# Node 2572 gives out ratings [1]
# Node 2570 gives out ratings [2, 5]
# Node 2567 gives out ratings [8, 9]
# Node 2573 gives out ratings [1]
# Node 2598 gives out ratings [-5, 2]
# Node 2574 gives out ratings [2]
# Node 2597 gives out ratings [-1, 1]
# Node 2592 gives out ratings [1]
# Node 2017 gives out ratings [1]
# Node 2603 gives out ratings [4, 8, 10]
# Node 2601 gives out ratings [3, 5, 7]
# Node 2602 gives out ratings []
# Node 2585 gives out ratings [1, 3]
# Node 2530 gives out ratings []
# Node 2617 gives out ratings []
# Node 2619 gives out ratings []
# Node 2622 gives out ratings [4, 9]
# Node 2623 gives out ratings [2, 4]
# Node 2621 gives out ratings []
# Node 2480 gives out ratings []
# Node 2561 gives out ratings [1]
# Node 2568 gives out ratings [1]
# Node 2629 gives out ratings []
# Node 2628 gives out ratings [10]
# Node 2632 gives out ratings [10]
# Node 2631 gives out ratings [10]
# Node 2634 gives out ratings []
# Node 2090 gives out ratings [1]
# Node 2606 gives out ratings [1]
# Node 925 gives out ratings [1]
# Node 2639 gives out ratings [1]
# Node 2640 gives out ratings [5]
# Node 2671 gives out ratings [5]
# Node 2657 gives out ratings [2]
# Node 2670 gives out ratings [9]
# Node 2672 gives out ratings [10]
# Node 2669 gives out ratings [2, 6]
# Node 2673 gives out ratings []
# Node 2633 gives out ratings []
# Node 1953 gives out ratings [1]
# Node 2173 gives out ratings [1]
# Node 2293 gives out ratings [1]
# Node 425 gives out ratings [1]
# Node 2674 gives out ratings [3]
# Node 2683 gives out ratings [-10]
# Node 2682 gives out ratings [10]
# Node 2680 gives out ratings [10]
# Node 2684 gives out ratings [-10]
# Node 2666 gives out ratings [2]
# Node 2694 gives out ratings [1]
# Node 2698 gives out ratings []
# Node 2697 gives out ratings []
# Node 2699 gives out ratings [10]
# Node 2700 gives out ratings [1, 5]
# Node 2701 gives out ratings [5]
# Node 2702 gives out ratings [1, 4, 5]
# Node 2704 gives out ratings [1]
# Node 2705 gives out ratings [3]
# Node 2703 gives out ratings [4]
# Node 2706 gives out ratings []
# Node 2707 gives out ratings []
# Node 2708 gives out ratings []
# Node 2709 gives out ratings []
# Node 2660 gives out ratings [1]
# Node 2636 gives out ratings [1]
# Node 2712 gives out ratings [3, 4]
# Node 2717 gives out ratings [1, 3, 4]
# Node 2718 gives out ratings [1]
# Node 2720 gives out ratings [10]
# Node 2722 gives out ratings []
# Node 2721 gives out ratings []
# Node 2735 gives out ratings [2]
# Node 2736 gives out ratings [2]
# Node 2676 gives out ratings [1]
# Node 2737 gives out ratings [2]
# Node 2678 gives out ratings [-4, 3, 9, 10]
# Node 2738 gives out ratings [1, 2, 10]
# Node 2741 gives out ratings []
# Node 2743 gives out ratings []
# Node 2744 gives out ratings [3]
# Node 2745 gives out ratings [2, 3]
# Node 2746 gives out ratings [1, 3]
# Node 2747 gives out ratings [2]
# Node 2749 gives out ratings []
# Node 2752 gives out ratings []
# Node 2753 gives out ratings []
# Node 2766 gives out ratings [1]
# Node 2757 gives out ratings [1]
# Node 2787 gives out ratings [2]
# Node 2714 gives out ratings [1, 2]
# Node 2778 gives out ratings [1, 2]
# Node 2675 gives out ratings [1, 9]
# Node 2689 gives out ratings []
# Node 2677 gives out ratings [3]
# Node 2543 gives out ratings [6]
# Node 2542 gives out ratings [4]
# Node 2544 gives out ratings [3]
# Node 2541 gives out ratings [2]
# Node 2545 gives out ratings [1]
# Node 2522 gives out ratings []
# Node 2695 gives out ratings [4]
# Node 1293 gives out ratings [-10, 4]
# Node 2581 gives out ratings [2]
# Node 2863 gives out ratings []
# Node 361 gives out ratings [1]
# Node 2868 gives out ratings [1]
# Node 2879 gives out ratings [-10, -9, -1]
# Node 2688 gives out ratings [1]
# Node 2811 gives out ratings [-10]
# Node 523 gives out ratings [1]
# Node 2635 gives out ratings [1]
# Node 2881 gives out ratings [-10]
# Node 1207 gives out ratings [1]
# Node 2887 gives out ratings [1]
# Node 242 gives out ratings [1, 2]
# Node 2891 gives out ratings [1]
# Node 2919 gives out ratings [1]
# Node 2926 gives out ratings []
# Node 1846 gives out ratings [5]
# Node 75 gives out ratings [2]
# Node 2028 gives out ratings [1]
# Node 2970 gives out ratings []
# Node 894 gives out ratings [1]
# Node 2067 gives out ratings [1]
# Node 1331 gives out ratings [4, 5]
# Node 2996 gives out ratings []
# Node 570 gives out ratings [1]
# Node 3015 gives out ratings [1]
# Node 3022 gives out ratings []
# Node 3019 gives out ratings [1]
# Node 3025 gives out ratings []
# Node 2992 gives out ratings [1, 8]
# Node 2815 gives out ratings []
# Node 3027 gives out ratings []
# Node 3059 gives out ratings [1]
# Node 2772 gives out ratings [1]
# Node 3108 gives out ratings []
# Node 3109 gives out ratings []
# Node 642 gives out ratings [1]
# Node 2897 gives out ratings [1]
# Node 2503 gives out ratings [1]
# Node 3159 gives out ratings []
# Node 3144 gives out ratings [-10]
# Node 3167 gives out ratings []
# Node 2343 gives out ratings [2]
# Node 2363 gives out ratings [2]
# Node 3061 gives out ratings []
# Node 2093 gives out ratings [1]
# Node 2275 gives out ratings [1]
# Node 3210 gives out ratings [5]
# Node 3197 gives out ratings [1]
# Node 2661 gives out ratings [2]
# Node 3273 gives out ratings [-10]
# Node 2388 gives out ratings [1]
# Node 2296 gives out ratings [1]
# Node 1403 gives out ratings [1]
# Node 3259 gives out ratings [1]
# Node 1271 gives out ratings [1]
# Node 3314 gives out ratings [-10]
# Node 1839 gives out ratings [2, 5, 8]
# Node 3193 gives out ratings [1]
# Node 3299 gives out ratings [1]
# Node 3066 gives out ratings []
# Node 2962 gives out ratings [1]
# Node 3333 gives out ratings [1]
# Node 3287 gives out ratings [1]
# Node 3036 gives out ratings [1]
# Node 3371 gives out ratings []
# Node 3372 gives out ratings []
# Node 3373 gives out ratings []
# Node 3366 gives out ratings [1]
# Node 3378 gives out ratings [-10]
# Node 3376 gives out ratings []
# Node 1890 gives out ratings [1]
# Node 3399 gives out ratings []
# Node 1334 gives out ratings [1]
# Node 3409 gives out ratings []
# Node 3410 gives out ratings [1]
# Node 1701 gives out ratings [1]
# Node 13 gives out ratings [1]
# Node 177 gives out ratings [1]
# Node 2690 gives out ratings [1]
# Node 3473 gives out ratings []
# Node 870 gives out ratings [1]
# Node 1352 gives out ratings [1]
# Node 3472 gives out ratings [1]
# Node 3436 gives out ratings []
# Node 3498 gives out ratings [5]
# Node 1566 gives out ratings [1]
# Node 3554 gives out ratings [10]
# Node 3553 gives out ratings [10]
# Node 3552 gives out ratings []
# Node 3558 gives out ratings [8]
# Node 3557 gives out ratings [1]
# Node 3556 gives out ratings [10]
# Node 3555 gives out ratings []
# Node 2898 gives out ratings [1]
# Node 3560 gives out ratings []
# Node 3562 gives out ratings [8]
# Node 3563 gives out ratings [10]
# Node 3564 gives out ratings [8]
# Node 3565 gives out ratings [8]
# Node 3566 gives out ratings [8]
# Node 3567 gives out ratings [10]
# Node 729 gives out ratings [1]
# Node 3570 gives out ratings [8]
# Node 3569 gives out ratings [10]
# Node 3463 gives out ratings [1]
# Node 3515 gives out ratings [2]
# Node 3466 gives out ratings [1]
# Node 3619 gives out ratings [1]
# Node 3665 gives out ratings [1]
# Node 1318 gives out ratings [-10]
# Node 3744 gives out ratings [10]
# Node 2725 gives out ratings [1]
# Node 3756 gives out ratings [-10]
# Node 3757 gives out ratings [-10]
# Node 3759 gives out ratings [-10]
# Node 3760 gives out ratings [-10]
# Node 3795 gives out ratings [-10]
# Node 3794 gives out ratings [-10]
# Node 3793 gives out ratings [-10]
# Node 3792 gives out ratings [-10]
# Node 3791 gives out ratings [-10]
# Node 3790 gives out ratings [-10]
# Node 3789 gives out ratings [-10]
# Node 3788 gives out ratings [-10]
# Node 3787 gives out ratings [-10]
# Node 3786 gives out ratings [-10]
# Node 3785 gives out ratings [10]
# Node 96 gives out ratings [1]
# Node 3797 gives out ratings [1, 3]
# Node 3208 gives out ratings [1, 3]
# Node 3866 gives out ratings []
# Node 1198 gives out ratings [1]
# Node 3993 gives out ratings [-10]
# Node 2405 gives out ratings [1]
# Node 3738 gives out ratings [2]
# Node 4081 gives out ratings []
# Node 1094 gives out ratings [1]
# Node 2333 gives out ratings [2]
# Node 4100 gives out ratings []
# Node 733 gives out ratings [2, 3]
# Node 1043 gives out ratings [1]
# Node 396 gives out ratings [1]
# Node 383 gives out ratings [1]
# Node 4138 gives out ratings []
# Node 4008 gives out ratings [1]
# Node 152 gives out ratings [1]
# Node 962 gives out ratings [1]
# Node 3715 gives out ratings [1]
# Node 4110 gives out ratings [-10, 1]
# Node 4182 gives out ratings []
# Node 2214 gives out ratings [1]
# Node 4251 gives out ratings [1]
# Node 21 gives out ratings [1]
# Node 2080 gives out ratings [1]
# Node 1675 gives out ratings [1]
# Node 2344 gives out ratings [1]
# Node 1562 gives out ratings [1]
# Node 571 gives out ratings [1]
# Node 1377 gives out ratings [1]
# Node 4275 gives out ratings []
# Node 3449 gives out ratings [1]
# Node 1809 gives out ratings [1]
# Node 4344 gives out ratings [1]
# Node 4290 gives out ratings [1, 2]
# Node 1257 gives out ratings [1, 2, 3]
# Node 2726 gives out ratings [1]
# Node 1792 gives out ratings [5]
# Node 499 gives out ratings [1]
# Node 4279 gives out ratings [1]
# Node 2158 gives out ratings [1]
# Node 1744 gives out ratings [1]
# Node 4350 gives out ratings [1, 4]
# Node 4404 gives out ratings []
# Node 3293 gives out ratings []
# Node 4375 gives out ratings [1]
# Node 4383 gives out ratings []
# Node 4405 gives out ratings [1]
# Node 4438 gives out ratings []
# Node 4184 gives out ratings [1]
# Node 4075 gives out ratings [1]
# Node 4443 gives out ratings [1, 2]
# Node 4432 gives out ratings [1]
# Node 786 gives out ratings [1]
# Node 1750 gives out ratings [2]
# Node 4492 gives out ratings []
# Node 3233 gives out ratings [1]
# Node 4501 gives out ratings [1]
# Node 4502 gives out ratings [1]
# Node 4450 gives out ratings [1]
# Node 4413 gives out ratings [1]
# Node 4531 gives out ratings [-10]
# Node 4535 gives out ratings [1]
# Node 2801 gives out ratings [1]
# Node 4544 gives out ratings []
# Node 4545 gives out ratings []
# Node 3445 gives out ratings [1, 2]
# Node 4315 gives out ratings [1, 3]
# Node 4406 gives out ratings [1]
# Node 4556 gives out ratings []
# Node 4543 gives out ratings [1]
# Node 4400 gives out ratings [1]
# Node 4546 gives out ratings [1, 2]
# Node 4269 gives out ratings [1]
# Node 4560 gives out ratings []
# Node 4563 gives out ratings [1]
# Node 2040 gives out ratings [2, 3]
# Node 204 gives out ratings [1]
# Node 2822 gives out ratings [2]
# Node 4571 gives out ratings [1]
# Node 4574 gives out ratings [2]
# Node 4084 gives out ratings [1]
# Node 4597 gives out ratings [1]
# Node 4587 gives out ratings [1]
# Node 4592 gives out ratings [1]
# Node 3578 gives out ratings [1]
# Node 4603 gives out ratings [1]
# Node 4613 gives out ratings [1]
# Node 4609 gives out ratings [-10]
# Node 4614 gives out ratings [1]
# Node 4621 gives out ratings [1]
# Node 4625 gives out ratings [1]
# Node 4627 gives out ratings [1]
# Node 1769 gives out ratings [2, 4, 5]
# Node 1044 gives out ratings [1]
# Node 4527 gives out ratings [1]
# Node 4647 gives out ratings [1]
# Node 4622 gives out ratings [-10, 1]
# Node 4654 gives out ratings [-10]
# Node 4656 gives out ratings [-10]
# Node 4659 gives out ratings [-10]
# Node 4637 gives out ratings [1]
# Node 481 gives out ratings [-10]
# Node 4661 gives out ratings [-10]
# Node 4666 gives out ratings [-10]
# Node 4673 gives out ratings [-10]
# Node 4672 gives out ratings [-10]
# Node 2045 gives out ratings [1]
# Node 4675 gives out ratings [-10]
# Node 4677 gives out ratings []
# Node 4681 gives out ratings [1]
# Node 4679 gives out ratings [1]
# Node 4668 gives out ratings [1]
# Node 4667 gives out ratings [1]
# Node 4669 gives out ratings [-10]
# Node 4676 gives out ratings [-10]
# Node 4678 gives out ratings [1]
# Node 4680 gives out ratings [-10, 1]
# Node 4682 gives out ratings [1]
# Node 4683 gives out ratings [-10]
# Node 4686 gives out ratings [-10]
# Node 4688 gives out ratings [-10]
# Node 4655 gives out ratings [1]
# Node 4684 gives out ratings [-10]
# Node 4687 gives out ratings [1]
# Node 4704 gives out ratings []
# Node 4701 gives out ratings [-10]
# Node 4706 gives out ratings []
# Node 4707 gives out ratings [-10]
# Node 4694 gives out ratings [1]
# Node 4645 gives out ratings [1]
# Node 4729 gives out ratings [-10]
# Node 4427 gives out ratings [1]
# Node 4731 gives out ratings [1]
# Node 4733 gives out ratings [-10]
# Node 905 gives out ratings [1]
# Node 4732 gives out ratings [1]
# Node 4458 gives out ratings [-10]
# Node 4735 gives out ratings [-10]
# Node 4478 gives out ratings [1]
# Node 4736 gives out ratings [2]
# Node 4635 gives out ratings [1]
# Node 2424 gives out ratings [1]
# Node 4569 gives out ratings [1, 3]
# Node 4737 gives out ratings []
# Node 4490 gives out ratings [1, 2]
# Node 4421 gives out ratings [-10]
# Node 4739 gives out ratings []
# Node 3531 gives out ratings [1, 2]
# Node 4742 gives out ratings [7]
# Node 3841 gives out ratings [2]
# Node 4741 gives out ratings [6]
# Node 3857 gives out ratings [-10]
# Node 4743 gives out ratings [-10]
# Node 4744 gives out ratings [-10]
# Node 4746 gives out ratings [1]
# Node 1565 gives out ratings [1]
# Node 1815 gives out ratings [-10]
# Node 4745 gives out ratings [-10]
# Node 4747 gives out ratings []
# Node 4748 gives out ratings [-10]
# Node 4751 gives out ratings [-10]
# Node 2322 gives out ratings [1]
# Node 3897 gives out ratings [1]
# Node 4766 gives out ratings []
# Node 4646 gives out ratings [2]
# Node 4662 gives out ratings [2]
# Node 4663 gives out ratings [4]
# Node 4664 gives out ratings [10]
# Node 4776 gives out ratings [1]
# Node 4756 gives out ratings [1]
# Node 4777 gives out ratings [5]
# Node 4796 gives out ratings [1]
# Node 4775 gives out ratings [1]
# Node 4698 gives out ratings [2]
# Node 3697 gives out ratings [-10, 1]
# Node 4804 gives out ratings [1]
# Node 4789 gives out ratings [1]
# Node 4793 gives out ratings [3]
# Node 4038 gives out ratings [1]
# Node 4802 gives out ratings [3]
# Node 3669 gives out ratings [1]
# Node 4818 gives out ratings [1]
# Node 4814 gives out ratings [1]
# Node 4831 gives out ratings []
# Node 4791 gives out ratings [-5, 1]
# Node 4236 gives out ratings [1]
# Node 4835 gives out ratings [2]
# Node 4843 gives out ratings []
# Node 3767 gives out ratings [1]
# Node 3646 gives out ratings [1]
# Node 4844 gives out ratings [1]
# Node 4871 gives out ratings [-1]
# Node 4857 gives out ratings [1]
# Node 4172 gives out ratings [1]
# Node 4870 gives out ratings [-10]
# Node 4883 gives out ratings [1]
# Node 4740 gives out ratings [2]
# Node 3642 gives out ratings [1]
# Node 4524 gives out ratings [2, 8]
# Node 4901 gives out ratings [1]
# Node 4566 gives out ratings [-5, 1]
# Node 4898 gives out ratings [1]
# Node 4026 gives out ratings [1]
# Node 4919 gives out ratings [1]
# Node 4379 gives out ratings [2, 4, 5]
# Node 3490 gives out ratings [1]
# Node 4965 gives out ratings [1]
# Node 4986 gives out ratings [1]
# Node 4980 gives out ratings [1]
# Node 4977 gives out ratings [-10]
# Node 4967 gives out ratings [-10, 1]
# Node 4996 gives out ratings [1]
# Node 4966 gives out ratings [1]
# Node 3270 gives out ratings [1]
# Node 5007 gives out ratings [1]
# Node 4330 gives out ratings [1]
# Node 3512 gives out ratings [1]
# Node 5021 gives out ratings [1]
# Node 3660 gives out ratings [1]
# Node 4528 gives out ratings [-10, 1]
# Node 5027 gives out ratings [1]
# Node 1535 gives out ratings [1]
# Node 4708 gives out ratings [1]
# Node 4244 gives out ratings [1]
# Node 4235 gives out ratings [1]
# Node 4122 gives out ratings [1]
# Node 5036 gives out ratings [4, 10]
# Node 5051 gives out ratings []
# Node 5037 gives out ratings [1, 2]
# Node 3 gives out ratings []
# Node 5072 gives out ratings [1]
# Node 5070 gives out ratings [2]
# Node 5069 gives out ratings [1]
# Node 5066 gives out ratings [1]
# Node 5067 gives out ratings [1, 2]
# Node 5068 gives out ratings [1]
# Node 5071 gives out ratings [1, 3]
# Node 1754 gives out ratings [1]
# Node 4254 gives out ratings [1]
# Node 3006 gives out ratings [1]
# Node 4988 gives out ratings [1, 2, 5]
# Node 5081 gives out ratings []
# Node 4934 gives out ratings []
# Node 5096 gives out ratings [-10, 10]
# Node 5086 gives out ratings [1]
# Node 4890 gives out ratings [1]
# Node 4434 gives out ratings [1]
# Node 5106 gives out ratings []
# Node 5108 gives out ratings []
# Node 5109 gives out ratings []
# Node 5110 gives out ratings []
# Node 5111 gives out ratings []
# Node 5112 gives out ratings []
# Node 5113 gives out ratings []
# Node 5083 gives out ratings []
# Node 574 gives out ratings [3]
# Node 1612 gives out ratings [1]
# Node 5115 gives out ratings [1]
# Node 5080 gives out ratings [-10, 5]
# Node 5129 gives out ratings [10]
# Node 5147 gives out ratings []
# Node 5148 gives out ratings []
# Node 5149 gives out ratings []
# Node 5150 gives out ratings []
# Node 5152 gives out ratings []
# Node 4198 gives out ratings [1]
# Node 5153 gives out ratings []
# Node 5154 gives out ratings []
# Node 5159 gives out ratings []
# Node 5160 gives out ratings []
# Node 5161 gives out ratings []
# Node 5164 gives out ratings []
# Node 5166 gives out ratings []
# Node 5167 gives out ratings []
# Node 5168 gives out ratings []
# Node 5170 gives out ratings []
# Node 5171 gives out ratings []
# Node 5172 gives out ratings []
# Node 5173 gives out ratings []
# Node 5174 gives out ratings []
# Node 5169 gives out ratings []
# Node 5116 gives out ratings []
# Node 5114 gives out ratings []
# Node 5107 gives out ratings []
# Node 5176 gives out ratings []
# Node 5177 gives out ratings []
# Node 5181 gives out ratings []
# Node 5182 gives out ratings []
# Node 5185 gives out ratings []
# Node 347 gives out ratings [1]
# Node 2399 gives out ratings [1]
# Node 5189 gives out ratings []
# Node 5190 gives out ratings []
# Node 5191 gives out ratings []
# Node 5196 gives out ratings []
# Node 5193 gives out ratings [-10]
# Node 5197 gives out ratings [-10]
# Node 5198 gives out ratings [-10]
# Node 4559 gives out ratings [1]
# Node 5199 gives out ratings [-10]
# Node 4899 gives out ratings [1]
# Node 3719 gives out ratings [1]
# Node 5200 gives out ratings [-10]
# Node 5201 gives out ratings [-10]
# Node 5202 gives out ratings [-10]
# Node 5203 gives out ratings [-10]
# Node 5204 gives out ratings []
# Node 5205 gives out ratings []
# Node 5206 gives out ratings []
# Node 5207 gives out ratings []
# Node 5209 gives out ratings []
# Node 5186 gives out ratings [1]
# Node 3743 gives out ratings []
# Node 1348 gives out ratings [1]
# Node 5210 gives out ratings []
# Node 5192 gives out ratings [1]
# Node 4983 gives out ratings [1]
# Node 2590 gives out ratings [1]
# Node 5214 gives out ratings []
# Node 5195 gives out ratings [1]
# Node 5215 gives out ratings [1]
# Node 5216 gives out ratings [1]
# Node 5222 gives out ratings []
# Node 5223 gives out ratings []
# Node 5076 gives out ratings [1]
# Node 5225 gives out ratings []
# Node 4840 gives out ratings [1]
# Node 777 gives out ratings [1]
# Node 5217 gives out ratings [1]
# Node 5230 gives out ratings []
# Node 5228 gives out ratings [1]
# Node 5231 gives out ratings [1]
# Node 5238 gives out ratings [-10]
# Node 5235 gives out ratings [-10, 1, 10]
# Node 5237 gives out ratings [10]
# Node 5239 gives out ratings [10]
# Node 5240 gives out ratings []
# Node 3776 gives out ratings [3]
# Node 5188 gives out ratings [-10]
# Node 5285 gives out ratings []
# Node 5304 gives out ratings []
# Node 5338 gives out ratings []
# Node 5364 gives out ratings []
# Node 5312 gives out ratings [-10, 1]
# Node 5370 gives out ratings [-10]
# Node 5371 gives out ratings []
# Node 5380 gives out ratings []
# Node 5378 gives out ratings []
# Node 5373 gives out ratings []
# Node 5374 gives out ratings []
# Node 5375 gives out ratings []
# Node 5376 gives out ratings []
# Node 5377 gives out ratings []
# Node 5379 gives out ratings []
# Node 5381 gives out ratings []
# Node 5382 gives out ratings []
# Node 5132 gives out ratings [2, 10]
# Node 1154 gives out ratings [1]
# Node 2187 gives out ratings [1]
# Node 5395 gives out ratings []
# Node 5396 gives out ratings []
# Node 62 gives out ratings [1]
# Node 4599 gives out ratings [1]
# Node 5367 gives out ratings [1]
# Node 5421 gives out ratings [1]
# Node 3988 gives out ratings [1]
# Node 5384 gives out ratings [1]
# Node 4812 gives out ratings [1]
# Node 5441 gives out ratings [-10]
# Node 1656 gives out ratings [2]
# Node 5346 gives out ratings []
# Node 4163 gives out ratings [1]
# Node 2755 gives out ratings [1]
# Node 5447 gives out ratings []
# Node 5448 gives out ratings [1]
# Node 5345 gives out ratings [1]
# Node 5454 gives out ratings []
# Node 5103 gives out ratings [2]
# Node 3380 gives out ratings [2]
# Node 5461 gives out ratings []
# Node 6 gives out ratings [1]
# Node 2987 gives out ratings [1]
# Node 5477 gives out ratings []
# Node 5471 gives out ratings [1]
# Node 4991 gives out ratings [1]
# Node 5213 gives out ratings [-10]
# Node 5479 gives out ratings [1]
# Node 5483 gives out ratings [-10, 1]
# Node 5484 gives out ratings [-10, 1]
# Node 5485 gives out ratings []
# Node 5363 gives out ratings [-10]
# Node 5488 gives out ratings []
# Node 5489 gives out ratings [-10]
# Node 5490 gives out ratings []
# Node 2013 gives out ratings [1, 5]
# Node 5532 gives out ratings []
# Node 5533 gives out ratings []
# Node 5142 gives out ratings [1]
# Node 4598 gives out ratings [1, 3]
# Node 5544 gives out ratings [4]
# Node 5546 gives out ratings []
# Node 5547 gives out ratings []
# Node 1964 gives out ratings [1]
# Node 3451 gives out ratings [1]
# Node 5480 gives out ratings [1]
# Node 5553 gives out ratings [1]
# Node 5576 gives out ratings []
# Node 4693 gives out ratings [1]
# Node 5599 gives out ratings []
# Node 5472 gives out ratings [1]
# Node 5610 gives out ratings [1]
# Node 5574 gives out ratings [-10, -1]
# Node 5554 gives out ratings [1]
# Node 5638 gives out ratings []
# Node 5641 gives out ratings []
# Node 5640 gives out ratings [2]
# Node 4136 gives out ratings [1]
# Node 5631 gives out ratings [1]
# Node 1991 gives out ratings [1]
# Node 5654 gives out ratings [3]
# Node 5686 gives out ratings []
# Node 3722 gives out ratings [1]
# Node 3452 gives out ratings [1]
# Node 5709 gives out ratings []
# Node 4649 gives out ratings [1]
# Node 4065 gives out ratings [-5, 1]
# Node 5227 gives out ratings [1]
# Node 5733 gives out ratings [-10]
# Node 5729 gives out ratings [3]
# Node 5732 gives out ratings [10]
# Node 5731 gives out ratings [10]
# Node 5730 gives out ratings [10]
# Node 5719 gives out ratings [1, 2, 10]
# Node 5736 gives out ratings [1]
# Node 5737 gives out ratings []
# Node 5738 gives out ratings [-10]
# Node 5556 gives out ratings [1]
# Node 1201 gives out ratings [2, 3]
# Node 5596 gives out ratings [1]
# Node 5609 gives out ratings [1]
# Node 5446 gives out ratings [1]
# Node 5255 gives out ratings [1]
# Node 5742 gives out ratings []
# Node 5525 gives out ratings [1]
# Node 5746 gives out ratings []
# Node 4382 gives out ratings [1]
# Node 4267 gives out ratings [1]
# Node 2784 gives out ratings [1]
# Node 5750 gives out ratings []
# Node 5635 gives out ratings [1]
# Node 5776 gives out ratings []
# Node 3129 gives out ratings [1]
# Node 3699 gives out ratings [1]
# Node 5791 gives out ratings [10]
# Node 5804 gives out ratings []
# Node 2647 gives out ratings [1]
# Node 5801 gives out ratings [1]
# Node 2942 gives out ratings [1]
# Node 5871 gives out ratings []
# Node 5872 gives out ratings []
# Node 5873 gives out ratings []
# Node 5874 gives out ratings []
# Node 5875 gives out ratings []
# Node 4326 gives out ratings []
# Node 4853 gives out ratings []
# Node 5243 gives out ratings []
# Node 5270 gives out ratings []
# Node 3384 gives out ratings []
# Node 5887 gives out ratings []
# Node 3345 gives out ratings [1]
# Node 3707 gives out ratings [1]
# Node 5898 gives out ratings []
# Node 2911 gives out ratings []
# Node 5901 gives out ratings []
# Node 5914 gives out ratings []
# Node 4570 gives out ratings [1]
# Node 4179 gives out ratings []
# Node 546 gives out ratings [1]
# Node 3470 gives out ratings [1, 8]
# Node 5608 gives out ratings [1]
# Node 3178 gives out ratings []
# Node 5549 gives out ratings [10]
# Node 5944 gives out ratings []
# Node 5650 gives out ratings [3]
# Node 5973 gives out ratings []
# Node 5975 gives out ratings []
# Node 5976 gives out ratings []
# Node 5977 gives out ratings []
# Node 5649 gives out ratings [3]
# Node 1272 gives out ratings [1]
# Node 5993 gives out ratings [1]
# Node 245 gives out ratings [1]
# Node 5655 gives out ratings [1]

# %%
rated_10_nodes = df[df['Rating'] == 10]['Target'].unique()
ratings_given_by_10_nodes = df[df['Source'].isin(rated_10_nodes)]['Rating']
mode_rating_given_by_10_nodes = ratings_given_by_10_nodes.mode().iloc[0]

# Nodes most commonly rated -10
rated_minus_10_nodes = df[df['Rating'] == -10]['Target'].unique()
ratings_given_by_minus_10_nodes = df[df['Source'].isin(rated_minus_10_nodes)]['Rating']
mode_rating_given_by_minus_10_nodes = ratings_given_by_minus_10_nodes.mode().iloc[0]

print(f"The mode rating given by nodes commonly rated 10 is {mode_rating_given_by_10_nodes}")
print(f"The mode rating given by nodes commonly rated -10 is {mode_rating_given_by_minus_10_nodes}")
# Out:
# The mode rating given by nodes commonly rated 10 is 1
# The mode rating given by nodes commonly rated -10 is 1

# %%
rated_10_nodes = df[df['Rating'] == 10]['Target'].unique()
ratings_given_by_10_nodes = df[df['Source'].isin(rated_10_nodes)]['Rating']
average_rating_given_by_10_nodes = ratings_given_by_10_nodes.mean()

# Nodes most commonly rated -10
rated_minus_10_nodes = df[df['Rating'] == -10]['Target'].unique()
ratings_given_by_minus_10_nodes = df[df['Source'].isin(rated_minus_10_nodes)]['Rating']
average_rating_given_by_minus_10_nodes = ratings_given_by_minus_10_nodes.mean()

print(f"The average rating given by nodes commonly rated 10 is {average_rating_given_by_10_nodes}")
print(f"The average rating given by nodes commonly rated -10 is {average_rating_given_by_minus_10_nodes}")
# Out:
# The average rating given by nodes commonly rated 10 is 0.8602346988967746
# The average rating given by nodes commonly rated -10 is -0.0001885369532428356

# %%
# Nodes rated between -10 and -3
rated_between_minus_10_and_minus_3_nodes = df[(df['Rating'] >= -10) & (df['Rating'] <= -3)]['Target'].unique()
ratings_given_by_minus_10_and_minus_3_nodes = df[df['Source'].isin(rated_between_minus_10_and_minus_3_nodes)]['Rating']
mode_rating_given_by_minus_10_and_minus_3_nodes = ratings_given_by_minus_10_and_minus_3_nodes.mode().iloc[0]

# Nodes rated between 3 and 10
rated_between_3_and_10_nodes = df[(df['Rating'] >= 3) & (df['Rating'] <= 10)]['Target'].unique()
ratings_given_by_3_and_10_nodes = df[df['Source'].isin(rated_between_3_and_10_nodes)]['Rating']
mode_rating_given_by_3_and_10_nodes = ratings_given_by_3_and_10_nodes.mode().iloc[0]

# Nodes rated between -3 and 3
rated_between_minus_3_and_3_nodes = df[(df['Rating'] >= -3) & (df['Rating'] <= 3)]['Target'].unique()
ratings_given_by_minus_3_and_3_nodes = df[df['Source'].isin(rated_between_minus_3_and_3_nodes)]['Rating']
mode_rating_given_by_minus_3_and_3_nodes = ratings_given_by_minus_3_and_3_nodes.mode().iloc[0]

print(f"The mode rating given by nodes rated between -10 and -3 is {mode_rating_given_by_minus_10_and_minus_3_nodes}")
print(f"The mode rating given by nodes rated between 3 and 10 is {mode_rating_given_by_3_and_10_nodes}")
print(f"The mode rating given by nodes rated between -3 and 3 is {mode_rating_given_by_minus_3_and_3_nodes}")
# Out:
# The mode rating given by nodes rated between -10 and -3 is 1
# The mode rating given by nodes rated between 3 and 10 is 1
# The mode rating given by nodes rated between -3 and 3 is 1

# %%
from statistics import mode

target_mode_ratings = df.groupby('Target')['Rating'].agg(lambda x: mode(x))

# Define the sub-range rating ranges
sub_rating_ranges = {
    'minus_3_to_0': (-3, 0),
    '0_to_3': (0, 3),
}

# Initialize a dictionary to hold the mode ratings for nodes in each sub-range
sub_range_mode_given = {}

# For each sub-range, find the nodes whose mode rating falls within that sub-range
for sub_range_name, (low, high) in sub_rating_ranges.items():
    # Nodes whose mode rating falls within the current sub-range
    nodes_in_sub_range = target_mode_ratings[(target_mode_ratings > low) & (target_mode_ratings <= high)].index.tolist()
    # All ratings given by these nodes
    ratings_given_by_nodes_in_sub_range = df[df['Source'].isin(nodes_in_sub_range)]['Rating']
    # Mode of the ratings given by these nodes
    mode_rating_given_by_nodes_in_sub_range = ratings_given_by_nodes_in_sub_range.mode().iloc[0] if not ratings_given_by_nodes_in_sub_range.empty else 'No mode rating'
    # Store the mode rating in the dictionary
    sub_range_mode_given[sub_range_name] = mode_rating_given_by_nodes_in_sub_range

# Print the mode rating for each sub-range
for sub_range_name, mode_rating in sub_range_mode_given.items():
    print(f"The mode rating given by nodes whose mode rating falls within {sub_range_name} is: {mode_rating}")
# Out:
# The mode rating given by nodes whose mode rating falls within minus_3_to_0 is: 1
# The mode rating given by nodes whose mode rating falls within 0_to_3 is: 1

# %%
# Nodes rated between -10 and -3
rated_between_minus_10_and_minus_3_nodes = df[(df['Rating'] >= -10) & (df['Rating'] <= -3)]['Target'].unique()
ratings_given_by_minus_10_and_minus_3_nodes = df[df['Source'].isin(rated_between_minus_10_and_minus_3_nodes)]['Rating']
average_rating_given_by_minus_10_and_minus_3_nodes = ratings_given_by_minus_10_and_minus_3_nodes.mean()

# Nodes rated between 3 and 10
rated_between_3_and_10_nodes = df[(df['Rating'] >= 3) & (df['Rating'] <= 10)]['Target'].unique()
ratings_given_by_3_and_10_nodes = df[df['Source'].isin(rated_between_3_and_10_nodes)]['Rating']
average_rating_given_by_3_and_10_nodes = ratings_given_by_3_and_10_nodes.mean()

# Nodes rated between -3 and 3
rated_between_minus_3_and_3_nodes = df[(df['Rating'] >= -3) & (df['Rating'] <= 3)]['Target'].unique()
ratings_given_by_minus_3_and_3_nodes = df[df['Source'].isin(rated_between_minus_3_and_3_nodes)]['Rating']
average_rating_given_by_minus_3_and_3_nodes = ratings_given_by_minus_3_and_3_nodes.mean()

print(f"The average rating given by nodes rated between -10 and -3 is {average_rating_given_by_minus_10_and_minus_3_nodes}")
print(f"The average rating given by nodes rated between 3 and 10 is {average_rating_given_by_3_and_10_nodes}")
print(f"The average rating given by nodes rated between -3 and 3 is {average_rating_given_by_minus_3_and_3_nodes}")
# Out:
# The average rating given by nodes rated between -10 and -3 is 0.1336097478422745
# The average rating given by nodes rated between 3 and 10 is 1.1562705426922797
# The average rating given by nodes rated between -3 and 3 is 1.1025980378053342

# %%
# Nodes rated between -10 and -3
rated_between_minus_10_and_minus_3_nodes = df[(df['Rating'] >= -10) & (df['Rating'] <= -3)]['Target'].unique()
ratings_given_by_minus_10_and_minus_3_nodes = df[df['Source'].isin(rated_between_minus_10_and_minus_3_nodes)]['Rating']
average_rating_given_by_minus_10_and_minus_3_nodes = ratings_given_by_minus_10_and_minus_3_nodes.mean()

# Nodes rated between -3 and 0
rated_between_minus_3_and_0_nodes = df[(df['Rating'] >= -3) & (df['Rating'] <= 0)]['Target'].unique()
ratings_given_by_minus_3_and_0_nodes = df[df['Source'].isin(rated_between_minus_3_and_0_nodes)]['Rating']
average_rating_given_by_minus_3_and_0_nodes = ratings_given_by_minus_3_and_0_nodes.mean()

# Nodes rated between 0 and 3
rated_between_0_and_3_nodes = df[(df['Rating'] > 0) & (df['Rating'] <= 3)]['Target'].unique()
ratings_given_by_0_and_3_nodes = df[df['Source'].isin(rated_between_0_and_3_nodes)]['Rating']
average_rating_given_by_0_and_3_nodes = ratings_given_by_0_and_3_nodes.mean()

# Nodes rated between 3 and 10
rated_between_3_and_10_nodes = df[(df['Rating'] >= 3) & (df['Rating'] <= 10)]['Target'].unique()
ratings_given_by_3_and_10_nodes = df[df['Source'].isin(rated_between_3_and_10_nodes)]['Rating']
average_rating_given_by_3_and_10_nodes = ratings_given_by_3_and_10_nodes.mean()

print(f"The average rating given by nodes rated between -10 and -3 is {average_rating_given_by_minus_10_and_minus_3_nodes}")
print(f"The average rating given by nodes rated between -3 and 0 is {average_rating_given_by_minus_3_and_0_nodes}")
print(f"The average rating given by nodes rated between 0 and 3 is {average_rating_given_by_0_and_3_nodes}")
print(f"The average rating given by nodes rated between 3 and 10 is {average_rating_given_by_3_and_10_nodes}")
# Out:
# The average rating given by nodes rated between -10 and -3 is 0.1336097478422745
# The average rating given by nodes rated between -3 and 0 is 0.8366826481689279
# The average rating given by nodes rated between 0 and 3 is 1.1038130097702972
# The average rating given by nodes rated between 3 and 10 is 1.1562705426922797

# %%
from statistics import multimode

modes = df.groupby('Target')['Rating'].agg(lambda x: multimode(x)[0] if multimode(x) else None)

# Define the ranges
range_min_10_min_3 = modes.between(-10, -4, inclusive='both')
range_3_10 = modes.between(4, 10, inclusive='both')
range_min_3_3 = modes.between(-3, 3, inclusive='both')

# Calculate the percentage of nodes whose mode falls within each range
percent_min_10_min_3 = range_min_10_min_3.sum() / len(modes) * 100
percent_3_10 = range_3_10.sum() / len(modes) * 100
percent_min_3_3 = range_min_3_3.sum() / len(modes) * 100

print(f"The percentage of nodes whose mode rating is between -10 and -4 is {percent_min_10_min_3:.2f}%")
print(f"The percentage of nodes whose mode rating is between 4 and 10 is {percent_3_10:.2f}%")
print(f"The percentage of nodes whose mode rating is between -3 and 3 is {percent_min_3_3:.2f}%")

# Sum the percentages to verify they add up to 100%.
total_percent = percent_min_10_min_3 + percent_3_10 + percent_min_3_3
print(f"The total percentage covered by these mode ranges is {total_percent:.2f}%")
# Out:
# The percentage of nodes whose mode rating is between -10 and -4 is 6.98%
# The percentage of nodes whose mode rating is between 4 and 10 is 5.21%
# The percentage of nodes whose mode rating is between -3 and 3 is 87.81%
# The total percentage covered by these mode ranges is 100.00%

# %%
from statistics import multimode

modes = df.groupby('Target')['Rating'].agg(lambda x: multimode(x)[0] if multimode(x) else None)

# Define the ranges
range_min_10_min_3 = modes.between(-10, -3, inclusive='both')
range_min_3_0 = modes.between(-3, 0, inclusive='left') & ~range_min_10_min_3
range_0_3 = modes.between(0, 3, inclusive='right') & ~range_min_10_min_3 & ~range_min_3_0
range_3_10 = modes.between(3, 10, inclusive='both') & ~range_min_10_min_3 & ~range_min_3_0 & ~range_0_3

# Calculate the percentage of nodes whose mode falls within each range
percent_min_10_min_3 = range_min_10_min_3.sum() / len(modes) * 100
percent_min_3_0 = range_min_3_0.sum() / len(modes) * 100
percent_0_3 = range_0_3.sum() / len(modes) * 100
percent_3_10 = range_3_10.sum() / len(modes) * 100

print(f"The percentage of nodes whose mode rating is between -10 and -3 is {percent_min_10_min_3:.2f}%")
print(f"The percentage of nodes whose mode rating is between -3 and 0 is {percent_min_3_0:.2f}%")
print(f"The percentage of nodes whose mode rating is between 0 and 3 is {percent_0_3:.2f}%")
print(f"The percentage of nodes whose mode rating is between 3 and 10 is {percent_3_10:.2f}%")

# Sum the percentages to verify they add up to 100%.
total_percent = percent_min_10_min_3 + percent_min_3_0 + percent_0_3 + percent_3_10
print(f"The total percentage covered by these mode ranges is {total_percent:.2f}%")
# Out:
# The percentage of nodes whose mode rating is between -10 and -3 is 7.08%
# The percentage of nodes whose mode rating is between -3 and 0 is 2.54%
# The percentage of nodes whose mode rating is between 0 and 3 is 85.17%
# The percentage of nodes whose mode rating is between 3 and 10 is 5.21%
# The total percentage covered by these mode ranges is 100.00%

# %%
# Function to initialize the fairness and goodness scores
def initialize_scores(G):
    fairness = {}
    goodness = {}

    # Initialize fairness to 1 and goodness based on in-degree and weights
    nodes = G.nodes()
    for node in nodes:
        fairness[node] = 1
        in_edges = G.in_edges(node, data='weight')
        if in_edges:  # Ensure there are incoming edges to avoid ZeroDivisionError
            goodness[node] = sum(weight for _, _, weight in in_edges) / len(in_edges)
        else:
            goodness[node] = 0
    return fairness, goodness

def normalize_scores(scores):
    max_score = max(abs(score) for score in scores.values())
    if max_score > 0:
        for node in scores:
            scores[node] /= max_score
    return scores

# Function to compute fairness and goodness
def compute_fairness_goodness(G):
    fairness, goodness = initialize_scores(G)
    nodes = G.nodes()
    iter = 0
    while iter < 100:
        df = 0
        dg = 0

        # Update goodness scores
        for node in nodes:
            inedges = G.in_edges(node, data='weight')
            if inedges:
                g = sum(fairness[edge[0]] * edge[2] for edge in inedges)
                new_goodness = g / len(inedges) if len(inedges) > 0 else 0
                dg += abs(new_goodness - goodness[node])
                goodness[node] = new_goodness

        # Normalize goodness to prevent overflow
        goodness = normalize_scores(goodness)

        # Update fairness scores
        for node in nodes:
            outedges = G.out_edges(node, data='weight')
            if outedges:
                f = sum(1.0 - abs(edge[2] - goodness[edge[1]]) / 2.0 for edge in outedges)
                new_fairness = f / len(outedges) if len(outedges) > 0 else 0
                df += abs(new_fairness - fairness[node])
                fairness[node] = new_fairness

        # Normalize fairness to prevent overflow
        fairness = normalize_scores(fairness)

        # Check for convergence
        if df < math.pow(10, -6) and dg < math.pow(10, -6):
            break

        iter += 1
    
    return fairness, goodness

# Create a directed graph from a pandas DataFrame
G = nx.DiGraph()

# Assuming 'df' is your DataFrame containing the data.
# Ensure that the 'Rating' column is converted to a float
for index, row in df.iterrows():
    G.add_edge(row['Source'], row['Target'], weight=float(row['Rating']))  # Convert rating to float

# Compute the fairness and goodness scores
fairness, goodness = compute_fairness_goodness(G)

# %%
df['Fairness'] = df['Source'].map(fairness)
df['Goodness'] = df['Target'].map(goodness)
df
# Out:
#        Source  Target  Rating        Time  Fairness  Goodness
# 0           6       2       4  1289241912 -0.159913 -0.042973
# 1           6       5       2  1289241942 -0.159913 -0.022760
# 2           1      15       1  1289243140 -0.080051 -0.001037
# 3           4       3       7  1289245277 -0.186980 -0.019818
# 4          13      16       8  1289254254 -0.017018 -0.013614
# ...       ...     ...     ...         ...       ...       ...
# 35587    4499    1810       1  1453612482 -0.030608  0.050283
# 35588    2731    3901       5  1453679428 -0.039879 -0.013105
# 35589    2731    4897       5  1453679434 -0.039879 -0.001126
# 35590      13    1128       1  1453679633 -0.017018  0.003272
# 35591    1128      13       2  1453684324  0.063473 -0.005218
#
# [35592 rows x 6 columns]

# %%
top_n = 10
top_fairness_nodes = sorted(fairness.items(), key=lambda item: item[1], reverse=True)[:top_n]

for node, fairness in top_fairness_nodes:
    print(f'Node {node} has a fairness of {fairness}')

top_n = 10
top_goodness_nodes = sorted(goodness.items(), key=lambda item: item[1], reverse=True)[:top_n]

for node, goodness in top_goodness_nodes:
    print(f'Node {node} has a goodness of {goodness}')
# Out:
# Node 4655.0 has a fairness of 0.1728309975598684
# Node 4433.0 has a fairness of 0.15097747805010683
# Node 2704.0 has a fairness of 0.14831916875179357
# Node 2718.0 has a fairness of 0.1407719346673379
# Node 5471.0 has a fairness of 0.13606198447874188
# Node 5704.0 has a fairness of 0.1318826743806233
# Node 4637.0 has a fairness of 0.1308094363068766
# Node 4600.0 has a fairness of 0.12900624743333383
# Node 2694.0 has a fairness of 0.12854806619627931
# Node 5086.0 has a fairness of 0.12854806619627931
# Node 3665.0 has a goodness of 1.0
# Node 4182.0 has a goodness of 1.0
# Node 4737.0 has a goodness of 0.8300908140971991
# Node 3786.0 has a goodness of 0.8257301937003192
# Node 3787.0 has a goodness of 0.8257301937003192
# Node 3788.0 has a goodness of 0.8257301937003192
# Node 3789.0 has a goodness of 0.8257301937003192
# Node 3790.0 has a goodness of 0.8257301937003192
# Node 3792.0 has a goodness of 0.8257301937003192
# Node 3791.0 has a goodness of 0.8257301937003192
